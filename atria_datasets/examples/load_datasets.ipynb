# %%
# %load_ext autoreload
# %autoreload 2

# %%
# first lets 
from atria_datasets import DATASET

available_modules = DATASET.list_all_modules()
print("Available dataset modules:")
for module in available_modules:
    print(f"- {module}")
# Out:
# Available dataset modules:
# - rvlcdip/image
# - rvlcdip/image_with_ocr
# - rvlcdip/image_with_ocr_1k
# - tobacco3482/image_only
# - tobacco3482/image_with_ocr
# - cifar10/1k
# - huggingface_cifar10/plain_text
# - huggingface_cifar10/plain_text_1k
# - doclaynet/default
# - doclaynet/1k
# - icdar2019/trackA_modern
# - icdar2019/trackA_archival
# - publaynet/default
# - publaynet/1k
# - cord
# - docbank/default
# - docbank/1k
# - docbank/0.1k
# - docile/kile
# - docile/lir
# - docile/kile_synthetic
# - docile/lir_synthetic
# - funsd
# - sroie
# - wild_receipts
# - fintabnet/default
# - fintabnet/1k
# - icdar2013
# - pubtables1m/detection
# - pubtables1m/detection_1k
# - pubtables1m/structure
# - pubtables1m/structure_1k
# - due_benchmark/DocVQA
# - due_benchmark/PWC
# - due_benchmark/DeepForm
# - due_benchmark/TabFact
# - due_benchmark/WikiTableQuestions
# - due_benchmark/InfographicsVQA
# - due_benchmark/KleisterCharity

# %%
# first lets load the image classification datasets
from atria_datasets import load_dataset_config

dataset_config = load_dataset_config("rvlcdip/image_with_ocr_1k")
dataset = dataset_config.build()
# Out:
# [2025-12-09 10:53:21][atria.atria_datasets.core.dataset._dataset_builders][WARNING] No 'data_dir' provided. Using default data dir directory: /media/saifullah/drive/work/ds/documents/datasets/rvlcdip
# [2025-12-09 10:53:21][atria.atria_datasets.core.dataset._dataset_builders][INFO] Downloaded files {'train.txt': PosixPath('/media/saifullah/drive/work/ds/documents/datasets/rvlcdip/train.txt'), 'test.txt': PosixPath('/media/saifullah/drive/work/ds/documents/datasets/rvlcdip/test.txt'), 'val.txt': PosixPath('/media/saifullah/drive/work/ds/documents/datasets/rvlcdip/val.txt'), 'rvl-cdip': PosixPath('/media/saifullah/drive/work/ds/documents/datasets/rvlcdip/rvl-cdip'), 'rvl-cdip-ocr': PosixPath('/media/saifullah/drive/work/ds/documents/datasets/rvlcdip/rvl-cdip-ocr')}

# %%
sample = next(iter(dataset.train))

# %%
sample
# Out:
# DocumentInstance(
#     index=0,
#     sample_id='80035521.tif',
#     annotations=[
#         ClassificationAnnotation(
#             type='classification',
#             label=Label(value=15, name='memo')
#         )
#     ],
#     page_id=None,
#     pdf=None,
#     image=Image(
#         file_path='rvl-cdip/images/imagesq/q/o/c/qoc54c00/80035521.tif',
#         content=<PIL.TiffImagePlugin.TiffImageFile image mode=L size=754x1000 at 0x7F91C9BBEE90>,
#         source_width=754,
#         source_height=1000,
#         width=754,
#         height=1000,
#         channels=1
#     ),
#     ocr=OCR(
#         file_path='rvl-cdip-ocr/images/imagesq/q/o/c/qoc54c00/80035521.hocr.lstm',
#         type=<OCRType.tesseract: 'tesseract'>,
#         content='<?xml version="1.0" encoding="UTF-8"?>\n<!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Transitional//EN"\n    "http://www.w3.org/TR/'+12930
#     ),
#     content=DocumentContent(
#         text='To: FROM: SUBJECT: According Materials in Beagle materials Seuslland MEMORANDUM, J.D. Heck A. P. Deaton Solubility of Materials '+304,
#         text_elements=[
#             TextElement(
#                 text='To:',
#                 bbox=BoundingBox(
#                     value=[
#                         0.14854111405835543,
#                         0.315,
#                         0.17771883289124668,
#                         0.323
#                     ],
#                     mode=<BoundingBoxMode.XYXY: 'xyxy'>,
#                     normalized=True
#                 ),
#                 segment_bbox=None,
#                 conf=77.0,
#                 angle=0.0
#             ),
#             TextElement(
#                 text='FROM:',
#                 bbox=BoundingBox(
#                     value=[
#                         0.14986737400530503,
#                         0.342,
#                         0.2002652519893899,
#                         0.351
#                     ],
#                     mode=<BoundingBoxMode.XYXY: 'xyxy'>,
#                     normalized=True
#                 ),
#                 segment_bbox=None,
#                 conf=87.0,
#                 angle=0.0
#             ),
#             TextElement(
#                 text='SUBJECT:',
#                 bbox=BoundingBox(
#                     value=[
#                         0.14854111405835543,
#                         0.369,
#                         0.23209549071618038,
#                         0.378
#                     ],
#                     mode=<BoundingBoxMode.XYXY: 'xyxy'>,
#                     normalized=True
#                 ),
#                 segment_bbox=None,
#                 conf=91.0,
#                 angle=0.0
#             ),
#             TextElement(
#                 text='According',
#                 bbox=BoundingBox(
#                     value=[
#                         0.14721485411140584,
#                         0.423,
#                         0.2453580901856764,
#                         0.435
#                     ],
#                     mode=<BoundingBoxMode.XYXY: 'xyxy'>,
#                     normalized=True
#                 ),
#                 segment_bbox=None,
#                 conf=96.0,
#                 angle=0.0
#             ),
#             ... +61
#         ]
#     )
# )
