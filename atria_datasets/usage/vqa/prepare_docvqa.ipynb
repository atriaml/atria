# %%
# %load_ext autoreload
# %autoreload 2

# %%
from atria_logger import get_logger
from atria_transforms.core import DataTransform
from atria_types import AnnotationType, DocumentInstance, QuestionAnsweringAnnotation

from atria_datasets import load_dataset_config

logger = get_logger(__name__)

dataset_config = load_dataset_config("due_benchmark/DocVQA")
dataset = dataset_config.build(max_cache_image_size=1024)
logger.info(f"Loaded dataset:\n{dataset}")
# Out:
# [2025-12-20 15:13:02][atria.atria_datasets.core.dataset._dataset_builders][WARNING] No 'data_dir' provided. Using default data dir directory: /mnt/zani/home/ataraxia/.atria/datasets/due_benchmark
# [2025-12-20 15:13:02][atria.atria_datasets.core.dataset._dataset_builders][INFO] Downloaded files {'DocVQA': PosixPath('/mnt/zani/home/ataraxia/.atria/datasets/due_benchmark/pdfs/DocVQA')}
# [2025-12-20 15:13:02][atria.__main__][INFO] Loaded dataset:
# DueBenchmark(
#     data_model=<class 'atria_types._data_instance._document_instance.DocumentInstance'>,
#     split_iterators={
#         <DatasetSplitType.train: 'train'>: SplitIterator(
#             base_iterator=<atria_datasets.registry.vqa.due.SplitIterator object at 0x75447c129f10>,
#             input_transform=<function DueBenchmark._input_transform at 0x754571b98c20>,
#             output_transform=<atria_datasets.core.dataset._dataset_builders.DefaultOutputTransformer object at 0x75447d84cf10>,
#             subset_indices=None,
#             num_rows='unknown'
#         ),
#         <DatasetSplitType.test: 'test'>: SplitIterator(
#             base_iterator=<atria_datasets.registry.vqa.due.SplitIterator object at 0x75447c124b50>,
#             input_transform=<function DueBenchmark._input_transform at 0x754571b98c20>,
#             output_transform=<atria_datasets.core.dataset._dataset_builders.DefaultOutputTransformer object at 0x75447d8906d0>,
#             subset_indices=None,
#             num_rows='unknown'
#         ),
#         <DatasetSplitType.validation: 'validation'>: SplitIterator(
#             base_iterator=<atria_datasets.registry.vqa.due.SplitIterator object at 0x75447d891250>,
#             input_transform=<function DueBenchmark._input_transform at 0x754571b98c20>,
#             output_transform=<atria_datasets.core.dataset._dataset_builders.DefaultOutputTransformer object at 0x75447d890590>,
#             subset_indices=None,
#             num_rows='unknown'
#         )
#     }
# )

# %%
# get first sample
sample = next(iter(dataset.train))

logger.info(f"First sample in train split:\n{sample}")
# Out:
# [2025-12-20 15:13:04][atria.__main__][INFO] First sample in train split:
# DocumentInstance(
#     index=0,
#     sample_id='xnbl0037_1-7978',
#     annotations=[
#         QuestionAnsweringAnnotation(
#             type='question_answering',
#             qa_pairs=[
#                 QAPair(
#                     id=0,
#                     question_text='what is the date mentioned in this letter?',
#                     answer_spans=[AnswerSpan(start=-1, end=-1, text='1/8/93')]
#                 ),
#                 QAPair(
#                     id=1,
#                     question_text='what is the contact person name mentioned in letter?',
#                     answer_spans=[
#                         AnswerSpan(start=16, end=17, text='p. carter')
#                     ]
#                 )
#             ]
#         )
#     ],
#     page_id=0,
#     pdf=PDF(file_path='pdfs/DocVQA/DocVQA/xnbl0037_1.pdf', num_pages=1),
#     image=Image(
#         file_path=None,
#         content=<PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=2542x3038 at 0x75447D804890>,
#         source_width=2542,
#         source_height=3038,
#         width=2542,
#         height=3038,
#         channels=3
#     ),
#     ocr=None,
#     content=DocumentContent(
#         text='Confidential RJRT PR APPROVAL DATE: Lu giAs PROPOSED RELEASE DATE: OU (ESSAY FOR RELEASE TO! CONTACT: P. CARTER ROUTE TO: Name I'+230,
#         text_elements=[
#             TextElement(
#                 text='Confidential',
#                 bbox=BoundingBox(
#                     value=[
#                         0.3422501966955153,
#                         0.01184990125082291,
#                         0.5806451612903226,
#                         0.07965766951942067
#                     ],
#                     mode=<BoundingBoxMode.XYXY: 'xyxy'>,
#                     normalized=True
#                 ),
#                 segment_bbox=None,
#                 conf=None,
#                 angle=None
#             ),
#             TextElement(
#                 text='RJRT',
#                 bbox=BoundingBox(
#                     value=[
#                         0.4087332808811959,
#                         0.09907834101382489,
#                         0.45436664044059794,
#                         0.11652402896642527
#                     ],
#                     mode=<BoundingBoxMode.XYXY: 'xyxy'>,
#                     normalized=True
#                 ),
#                 segment_bbox=None,
#                 conf=None,
#                 angle=None
#             ),
#             TextElement(
#                 text='PR',
#                 bbox=BoundingBox(
#                     value=[
#                         0.46223446105428795,
#                         0.10039499670836076,
#                         0.48701809598741147,
#                         0.11652402896642527
#                     ],
#                     mode=<BoundingBoxMode.XYXY: 'xyxy'>,
#                     normalized=True
#                 ),
#                 segment_bbox=None,
#                 conf=None,
#                 angle=None
#             ),
#             TextElement(
#                 text='APPROVAL',
#                 bbox=BoundingBox(
#                     value=[
#                         0.4948859166011015,
#                         0.10039499670836076,
#                         0.5845790715971676,
#                         0.11652402896642527
#                     ],
#                     mode=<BoundingBoxMode.XYXY: 'xyxy'>,
#                     normalized=True
#                 ),
#                 segment_bbox=None,
#                 conf=None,
#                 angle=None
#             ),
#             ... +48
#         ]
#     )
# )
# DEFAULT /mnt/zani/home/ataraxia/.atria/datasets/due_benchmark DocumentInstance(
#     index=0,
#     sample_id='xnbl0037_1-7978',
#     annotations=[
#         QuestionAnsweringAnnotation(
#             type='question_answering',
#             qa_pairs=[
#                 QAPair(
#                     id=0,
#                     question_text='what is the date mentioned in this letter?',
#                     answer_spans=[AnswerSpan(start=-1, end=-1, text='1/8/93')]
#                 ),
#                 QAPair(
#                     id=1,
#                     question_text='what is the contact person name mentioned in letter?',
#                     answer_spans=[
#                         AnswerSpan(start=16, end=17, text='p. carter')
#                     ]
#                 )
#             ]
#         )
#     ],
#     page_id=0,
#     pdf=PDF(
#         file_path='/mnt/zani/home/ataraxia/.atria/datasets/due_benchmark/pdfs/DocVQA/DocVQA/xnbl0037_1.pdf',
#         num_pages=1
#     ),
#     image=Image(
#         file_path=None,
#         content=<PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=2542x3038 at 0x75447D804890>,
#         source_width=2542,
#         source_height=3038,
#         width=2542,
#         height=3038,
#         channels=3
#     ),
#     ocr=None,
#     content=DocumentContent(
#         text='Confidential RJRT PR APPROVAL DATE: Lu giAs PROPOSED RELEASE DATE: OU (ESSAY FOR RELEASE TO! CONTACT: P. CARTER ROUTE TO: Name I'+230,
#         text_elements=[
#             TextElement(
#                 text='Confidential',
#                 bbox=BoundingBox(
#                     value=[
#                         0.3422501966955153,
#                         0.01184990125082291,
#                         0.5806451612903226,
#                         0.07965766951942067
#                     ],
#                     mode=<BoundingBoxMode.XYXY: 'xyxy'>,
#                     normalized=True
#                 ),
#                 segment_bbox=None,
#                 conf=None,
#                 angle=None
#             ),
#             TextElement(
#                 text='RJRT',
#                 bbox=BoundingBox(
#                     value=[
#                         0.4087332808811959,
#                         0.09907834101382489,
#                         0.45436664044059794,
#                         0.11652402896642527
#                     ],
#                     mode=<BoundingBoxMode.XYXY: 'xyxy'>,
#                     normalized=True
#                 ),
#                 segment_bbox=None,
#                 conf=None,
#                 angle=None
#             ),
#             TextElement(
#                 text='PR',
#                 bbox=BoundingBox(
#                     value=[
#                         0.46223446105428795,
#                         0.10039499670836076,
#                         0.48701809598741147,
#                         0.11652402896642527
#                     ],
#                     mode=<BoundingBoxMode.XYXY: 'xyxy'>,
#                     normalized=True
#                 ),
#                 segment_bbox=None,
#                 conf=None,
#                 angle=None
#             ),
#             TextElement(
#                 text='APPROVAL',
#                 bbox=BoundingBox(
#                     value=[
#                         0.4948859166011015,
#                         0.10039499670836076,
#                         0.5845790715971676,
#                         0.11652402896642527
#                     ],
#                     mode=<BoundingBoxMode.XYXY: 'xyxy'>,
#                     normalized=True
#                 ),
#                 segment_bbox=None,
#                 conf=None,
#                 angle=None
#             ),
#             ... +48
#         ]
#     )
# )

# %%
import re
from atria_types import QAPair


class UnrollQAPairsTransform(DataTransform[list[DocumentInstance]]):
    remove_no_answer_samples: bool = False

    def __call__(self, document_instance: DocumentInstance) -> list[DocumentInstance]:
        qa_annotations = document_instance.get_annotation_by_type(
            annotation_type=AnnotationType.question_answering
        )

        document_instance_per_qa_pair = []
        for qa_pair in qa_annotations.qa_pairs:
            annotation = QuestionAnsweringAnnotation(qa_pairs=[qa_pair])

            def has_answer(qa_pair: QAPair):
                for answer_span in qa_pair.answer_spans:
                    if answer_span.start != -1 and answer_span.end != -1:
                        return True
                return False

            assert qa_pair.answer_spans is not None
            if self.remove_no_answer_samples:
                if not has_answer(qa_pair):
                    logger.debug(
                        f"Skipping QA Pair with id {qa_pair.id} due to no answer spans."
                    )
                    continue

            new_document_instance = document_instance.model_copy(
                update={
                    "sample_id": f"{document_instance.sample_id}_qa_{qa_pair.id}",
                    "annotations": [annotation],
                }
            )
            document_instance_per_qa_pair.append(new_document_instance)
        
        return document_instance_per_qa_pair


transform = UnrollQAPairsTransform(remove_no_answer_samples=True)
processed_sample = transform(sample)
for i, s in enumerate(processed_sample):
    logger.info(
        "Index: {}, Sample Id: {}, QA Pair: {}".format(
            i,
            s.sample_id,
            s.get_annotation_by_type(
                annotation_type=AnnotationType.question_answering
            ).qa_pairs[0],
        )
    )
logger.info(f"First sample after processing:\n{processed_sample}")
# Out:
# [2025-12-20 15:13:07][atria.__main__][INFO] Index: 0, Sample Id: xnbl0037_1-7978_qa_1, QA Pair: QAPair(
#     id=1,
#     question_text='what is the contact person name mentioned in letter?',
#     answer_spans=[AnswerSpan(start=16, end=17, text='p. carter')]
# )
# [2025-12-20 15:13:07][atria.__main__][INFO] First sample after processing:
# [DocumentInstance(
#     index=0,
#     sample_id='xnbl0037_1-7978_qa_1',
#     annotations=[
#         QuestionAnsweringAnnotation(
#             type='question_answering',
#             qa_pairs=[
#                 QAPair(
#                     id=1,
#                     question_text='what is the contact person name mentioned in letter?',
#                     answer_spans=[
#                         AnswerSpan(start=16, end=17, text='p. carter')
#                     ]
#                 )
#             ]
#         )
#     ],
#     page_id=0,
#     pdf=PDF(file_path='pdfs/DocVQA/DocVQA/xnbl0037_1.pdf', num_pages=1),
#     image=Image(
#         file_path=None,
#         content=<PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=2542x3038 at 0x75447D804890>,
#         source_width=2542,
#         source_height=3038,
#         width=2542,
#         height=3038,
#         channels=3
#     ),
#     ocr=None,
#     content=DocumentContent(
#         text='Confidential RJRT PR APPROVAL DATE: Lu giAs PROPOSED RELEASE DATE: OU (ESSAY FOR RELEASE TO! CONTACT: P. CARTER ROUTE TO: Name I'+230,
#         text_elements=[
#             TextElement(
#                 text='Confidential',
#                 bbox=BoundingBox(
#                     value=[
#                         0.3422501966955153,
#                         0.01184990125082291,
#                         0.5806451612903226,
#                         0.07965766951942067
#                     ],
#                     mode=<BoundingBoxMode.XYXY: 'xyxy'>,
#                     normalized=True
#                 ),
#                 segment_bbox=None,
#                 conf=None,
#                 angle=None
#             ),
#             TextElement(
#                 text='RJRT',
#                 bbox=BoundingBox(
#                     value=[
#                         0.4087332808811959,
#                         0.09907834101382489,
#                         0.45436664044059794,
#                         0.11652402896642527
#                     ],
#                     mode=<BoundingBoxMode.XYXY: 'xyxy'>,
#                     normalized=True
#                 ),
#                 segment_bbox=None,
#                 conf=None,
#                 angle=None
#             ),
#             TextElement(
#                 text='PR',
#                 bbox=BoundingBox(
#                     value=[
#                         0.46223446105428795,
#                         0.10039499670836076,
#                         0.48701809598741147,
#                         0.11652402896642527
#                     ],
#                     mode=<BoundingBoxMode.XYXY: 'xyxy'>,
#                     normalized=True
#                 ),
#                 segment_bbox=None,
#                 conf=None,
#                 angle=None
#             ),
#             TextElement(
#                 text='APPROVAL',
#                 bbox=BoundingBox(
#                     value=[
#                         0.4948859166011015,
#                         0.10039499670836076,
#                         0.5845790715971676,
#                         0.11652402896642527
#                     ],
#                     mode=<BoundingBoxMode.XYXY: 'xyxy'>,
#                     normalized=True
#                 ),
#                 segment_bbox=None,
#                 conf=None,
#                 angle=None
#             ),
#             ... +48
#         ]
#     )
# )]

# %%
from atria_datasets.core.dataset._dataset_builders import DefaultOutputTransformer
from atria_datasets.core.dataset._dataset_processor import DatasetProcessor

processed_dataset = dataset.process_dataset(transform=UnrollQAPairsTransform(), num_processes=0)
# Out:
# [2025-12-20 15:13:27][atria.atria_datasets.core.dataset._dataset_processor][INFO] Caching split [train] to /mnt/zani/home/ataraxia/.atria/datasets/due_benchmark/storage with max_len=None
# [2025-12-20 15:13:27][atria.atria_datasets.core.storage.msgpack_storage_manager][INFO] Preprocessing dataset split train to cached msgpack storage /mnt/zani/home/ataraxia/.atria/datasets/due_benchmark/storage/DocVQA-8d69bc02/a1f24409/msgpack/train
# Writing split train: 0it [00:00, ?it/s]
# [2025-12-20 15:13:28][atria.atria_datasets.core.storage.msgpack_storage_manager][INFO] Purging dataset split train from storage /mnt/zani/home/ataraxia/.atria/datasets/due_benchmark/storage/DocVQA-8d69bc02/a1f24409/msgpack/train.
# DEFAULT /mnt/zani/home/ataraxia/.atria/datasets/due_benchmark DocumentInstance(
#     index=0,
#     sample_id='xnbl0037_1-4238',
#     annotations=[
#         QuestionAnsweringAnnotation(
#             type='question_answering',
#             qa_pairs=[
#                 QAPair(
#                     id=0,
#                     question_text='what is the date mentioned in this letter?',
#                     answer_spans=[AnswerSpan(start=-1, end=-1, text='1/8/93')]
#                 ),
#                 QAPair(
#                     id=1,
#                     question_text='what is the contact person name mentioned in letter?',
#                     answer_spans=[
#                         AnswerSpan(start=16, end=17, text='p. carter')
#                     ]
#                 )
#             ]
#         )
#     ],
#     page_id=0,
#     pdf=PDF(
#         file_path='/mnt/zani/home/ataraxia/.atria/datasets/due_benchmark/pdfs/DocVQA/DocVQA/xnbl0037_1.pdf',
#         num_pages=1
#     ),
#     image=Image(
#         file_path=None,
#         content=<PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=2542x3038 at 0x75446E7F3310>,
#         source_width=2542,
#         source_height=3038,
#         width=2542,
#         height=3038,
#         channels=3
#     ),
#     ocr=None,
#     content=DocumentContent(
#         text='Confidential RJRT PR APPROVAL DATE: Lu giAs PROPOSED RELEASE DATE: OU (ESSAY FOR RELEASE TO! CONTACT: P. CARTER ROUTE TO: Name I'+230,
#         text_elements=[
#             TextElement(
#                 text='Confidential',
#                 bbox=BoundingBox(
#                     value=[
#                         0.3422501966955153,
#                         0.01184990125082291,
#                         0.5806451612903226,
#                         0.07965766951942067
#                     ],
#                     mode=<BoundingBoxMode.XYXY: 'xyxy'>,
#                     normalized=True
#                 ),
#                 segment_bbox=None,
#                 conf=None,
#                 angle=None
#             ),
#             TextElement(
#                 text='RJRT',
#                 bbox=BoundingBox(
#                     value=[
#                         0.4087332808811959,
#                         0.09907834101382489,
#                         0.45436664044059794,
#                         0.11652402896642527
#                     ],
#                     mode=<BoundingBoxMode.XYXY: 'xyxy'>,
#                     normalized=True
#                 ),
#                 segment_bbox=None,
#                 conf=None,
#                 angle=None
#             ),
#             TextElement(
#                 text='PR',
#                 bbox=BoundingBox(
#                     value=[
#                         0.46223446105428795,
#                         0.10039499670836076,
#                         0.48701809598741147,
#                         0.11652402896642527
#                     ],
#                     mode=<BoundingBoxMode.XYXY: 'xyxy'>,
#                     normalized=True
#                 ),
#                 segment_bbox=None,
#                 conf=None,
#                 angle=None
#             ),
#             TextElement(
#                 text='APPROVAL',
#                 bbox=BoundingBox(
#                     value=[
#                         0.4948859166011015,
#                         0.10039499670836076,
#                         0.5845790715971676,
#                         0.11652402896642527
#                     ],
#                     mode=<BoundingBoxMode.XYXY: 'xyxy'>,
#                     normalized=True
#                 ),
#                 segment_bbox=None,
#                 conf=None,
#                 angle=None
#             ),
#             ... +48
#         ]
#     )
# )
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /mnt/noel/phd-2026/projects/atria/atria_datasets/src/atria_datasets/core/storage/msgpack_storage_manager.py:295, in MsgpackStorageManager.write_split(self, split_iterator)
#     294 try:
# --> 295     self._write(split_iterator=split_iterator)
#     296 except Exception as e:
#
# File /mnt/noel/phd-2026/projects/atria/atria_datasets/src/atria_datasets/core/storage/msgpack_storage_manager.py:387, in MsgpackStorageManager._write(self, split_iterator)
#     385 else:
#     386     # --- Single-process mode ---
# --> 387     write_info = write_split_single(
#     388         split_iterator=split_iterator,
#     389         storage_dir=str(self._storage_dir),
#     390         config_name=self._config_name,
#     391         max_shard_size=self._max_shard_size,
#     392     )
#     394 # Log the writing results
#
# File /mnt/noel/phd-2026/projects/atria/atria_datasets/src/atria_datasets/core/storage/msgpack_storage_manager.py:24, in write_split_single(split_iterator, storage_dir, config_name, max_shard_size)
#      23 import tqdm
# ---> 24 from atria_logger import get_logger
#      26 from atria_datasets.core.storage.online_shard_writer_actor import OnlineShardWriter
#
# File /mnt/noel/phd-2026/projects/atria/atria_datasets/src/atria_datasets/core/storage/online_shard_writer_actor.py:108, in OnlineShardWriter.write(self, index, sample)
#     107 else:
# --> 108     self._writer.write({**sample.model_dump(), "key": sample.key})
#     110 # Update current shard info
#
# AttributeError: 'list' object has no attribute 'model_dump'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[17], line 4
#       1 from atria_datasets.core.dataset._dataset_builders import DefaultOutputTransformer
#       2 from atria_datasets.core.dataset._dataset_processor import DatasetProcessor
# ----> 4 processed_dataset = dataset.process_dataset(transform=UnrollQAPairsTransform(), num_processes=0)
#
# File /mnt/noel/phd-2026/projects/atria/atria_datasets/src/atria_datasets/core/dataset/_datasets.py:211, in Dataset.process_dataset(self, transform, split, processed_data_dir, cached_storage_type, overwrite_existing_cached, store_artifact_content, max_cache_image_size, num_processes)
#     198 """Process the entire dataset and return a new Dataset instance."""
#     199 from atria_datasets.core.dataset._dataset_processor import DatasetProcessor
#     201 split_iterators = DatasetProcessor(
#     202     dataset=self,
#     203     transform=transform,
#     204     split=split,
#     205     data_dir=processed_data_dir,
#     206     cached_storage_type=cached_storage_type,
#     207     overwrite_existing_cached=overwrite_existing_cached,
#     208     store_artifact_content=store_artifact_content,
#     209     max_cache_image_size=max_cache_image_size,
#     210     num_processes=num_processes,
# --> 211 ).process_splits()
#     212 self._split_iterators.update(split_iterators)
#     213 return self
#
# File /mnt/noel/phd-2026/projects/atria/atria_datasets/src/atria_datasets/core/dataset/_dataset_processor.py:194, in DatasetProcessor.process_splits(self)
#     185 split_iterator = self._prepare_split(
#     186     split=split,
#     187     store_artifact_content=self._store_artifact_content,
#     188     resize_images=self._max_cache_image_size is not None,
#     189     image_max_size=self._max_cache_image_size,
#     190 )
#     191 logger.info(
#     192     f"Caching split [{split.value}] to {self._storage_dir} with max_len={split_iterator._max_len}"
#     193 )
# --> 194 storage_manager.write_split(split_iterator=split_iterator)
#     195 if not info_saved:
#     196     _save_dataset_info(
#     197         self._storage_dir,
#     198         self.dataset_config.config_name,
#     199         self.dataset_config.model_dump(),
#     200         self.dataset_metadata.model_dump(),
#     201     )
#
# File /mnt/noel/phd-2026/projects/atria/atria_datasets/src/atria_datasets/core/storage/msgpack_storage_manager.py:298, in MsgpackStorageManager.write_split(self, split_iterator)
#     296 except Exception as e:
#     297     self.purge_split(split_iterator.split)
# --> 298     raise RuntimeError(
#     299         f"Error while writing dataset split {split_iterator.split.value} to storage. Cleaning up..."
#     300     ) from e
#     301 except KeyboardInterrupt as e:
#     302     self.purge_split(split_iterator.split)
#
# RuntimeError: Error while writing dataset split train to storage. Cleaning up...
